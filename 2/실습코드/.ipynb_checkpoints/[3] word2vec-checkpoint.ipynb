# %% [markdown]
# # Chapter3. word2vec

# %%
from IPython.display import Image
import numpy as np

# %% [markdown]
# ## 3.1 추론 기반 기법과 신경망

# %% [markdown]
# ### 3.1.1 통계 기반 기법의 문제점

# %% [markdown]
# - 대규모 말뭉치에 SVD를 적용할 경우 밀집벡터를 얻는데 상당한 컴퓨팅 자원을 들여야 함
# - 말뭉치 전체의 통계를 이용해 단 한 번의 처리만에 분산표현을 얻음

# %%
Image("image/fig 3-1.png")

# %% [markdown]
# 통계 기반 기법은 학습 데이터를 한꺼번에 처리, **추론 기반 기법은 미니배치 학습 활용** -> 계산량이 큰 작업을 처리하기 어려운 경우에도 학습 가능, GPU를 이용한 병렬계산 가능

# %% [markdown]
# ### 3.1.2 추론 기반 기법 개요

# %%
Image("image/fig 3-2.png")

# %%
Image("image/fig 3-3.png")

# %% [markdown]
# - 추론 기반 기법에는 맥락 정보를 입력받아 각 단어의 출현 확률을 출력하는 '모델'이 등장
# - 틀 안에서 말뭉치를 사용해 모델이 올바른 추측을 내놓도록 학습
# - 그 학습의 결과로 단어의 분산 표현을 얻는 것이 목표!

# %% [markdown]
# ### 3.1.3 신경망에서의 단어 처리
#
# 단어를 '고정 길이의 벡터'로 변환하는 과정이 필요 -> **원핫 벡터**

# %%
Image("image/fig 3-5.png")

# %%
Image("image/fig 3-8.png")

# %% [markdown]
# **-> 가중치의 행벡터 하나를 뽑아낸 것과 같음!**

# %% [markdown]
# ## 3.2 단순한 word2vec

# %% [markdown]
# ### 3.2.1 CBOW 모델의 추론 처리

# %%
Image("image/fig 3-11.png")

# %% [markdown]
# - 입력 층이 여러 개이면 전체를 평균
# - 은닉층의 뉴런 수는 입력층의 뉴런 수보다 적게!
# - 최종적으로 각 단어의 score을 구함

# %%
import sys
sys.path.append('..')
from common.layers import MatMul


# 샘플 맥락 데이터
c0 = np.array([[1, 0, 0, 0, 0, 0, 0]])
c1 = np.array([[0, 0, 1, 0, 0, 0, 0]])

# 가중치 초기화
W_in = np.random.randn(7, 3)
W_out = np.random.randn(3, 7)

# 계층 생성
in_layer0 = MatMul(W_in)
in_layer1 = MatMul(W_in)
out_layer = MatMul(W_out)

# 순전파
h0 = in_layer0.forward(c0)
h1 = in_layer1.forward(c1)
h = 0.5 * (h0 + h1)
s = out_layer.forward(h)
print(s)
# Out:
# [[ 0.30648161 -0.5192838   0.35052887  0.73339608 -1.7534675   0.44842581
#    1.46077145]]

# %% [markdown]
# ### 3.2.2 CBOW 모델의 학습

# %%
Image("image/fig 3-14.png")

# %% [markdown]
# - 가중치가 적절히 설정된 신경망이라면 확률을 나타내는 뉴런들 중 정답에 해당하는 뉴런의 값이 클 것이라 기대할 수 있음
# - CBOW 모델은 단어 출현 패턴을 학습 시 사용한 말뭉치로부터 배움 -> 말뭉치가 다르면 학습 후 얻게 되는 단어의 분산 표현도 달라짐
# - 소프트맥스 함수를 이용해 점수를 확률로 변환하고, 정답 레이블로부터 교차 엔트로피 오차를 구한 후 그 값을 손실로 사용해 학습을 진행

# %% [markdown]
# ### 3.2.3 word2vec의 가중치와 분산 표현

# %%
Image("image/fig 3-15.png")

# %% [markdown]
# **word2vec에서는 입력 측의 가중치만 이용하는 경우가 많음!!**

# %% [markdown]
# ## 3.3 학습 데이터 준비

# %% [markdown]
# ### 3.3.1 맥락과 타깃

# %% [markdown]
# - 입력 = **'맥락'**, 정답 레이블 = **'타깃'**
# - 신경망에 '맥락'을 입력했을 때 '타깃'이 출현할 확률을 높이도록...

# %%
Image("image/fig 3-16.png")

# %%
# 맥락과 타깃을 만드는 함수 구현

def create_contexts_target(corpus, window_size=1):

    target = corpus[window_size:-window_size]
    contexts = []

    for idx in range(window_size, len(corpus)-window_size):
        cs = []
        for t in range(-window_size, window_size + 1):
            if t == 0:
                continue
            cs.append(corpus[idx + t])
        contexts.append(cs)

    return np.array(contexts), np.array(target)

# %% [markdown]
# ### 3.3.2 원핫 표현으로 변환

# %%
Image("image/fig 3-18.png")

# %%
def convert_one_hot(corpus, vocab_size):
    
    
    N = corpus.shape[0]

    if corpus.ndim == 1:
        one_hot = np.zeros((N, vocab_size), dtype=np.int32)
        for idx, word_id in enumerate(corpus):
            one_hot[idx, word_id] = 1

    elif corpus.ndim == 2:
        C = corpus.shape[1]
        one_hot = np.zeros((N, C, vocab_size), dtype=np.int32)
        for idx_0, word_ids in enumerate(corpus):
            for idx_1, word_id in enumerate(word_ids):
                one_hot[idx_0, idx_1, word_id] = 1

    return one_hot

# %% [markdown]
# ## 3.4 CBOW 모델 구현

# %%
import sys
sys.path.append('..')
from common.layers import MatMul, SoftmaxWithLoss


class SimpleCBOW:
    
    def __init__(self, vocab_size, hidden_size):
        
        V, H = vocab_size, hidden_size

        # 가중치 초기화
        W_in = 0.01 * np.random.randn(V, H).astype('f')
        W_out = 0.01 * np.random.randn(H, V).astype('f')

        # 계층 생성
        self.in_layer0 = MatMul(W_in)
        self.in_layer1 = MatMul(W_in)
        self.out_layer = MatMul(W_out)
        self.loss_layer = SoftmaxWithLoss()

        # 모든 가중치와 기울기를 리스트에 모은다.
        layers = [self.in_layer0, self.in_layer1, self.out_layer]
        self.params, self.grads = [], []
        for layer in layers:
            self.params += layer.params
            self.grads += layer.grads

        # 인스턴스 변수에 단어의 분산 표현을 저장한다
        self.word_vecs = W_in

    def forward(self, contexts, target):
        
        h0 = self.in_layer0.forward(contexts[:, 0])
        h1 = self.in_layer1.forward(contexts[:, 1])
        h = (h0 + h1) * 0.5
        score = self.out_layer.forward(h)
        loss = self.loss_layer.forward(score, target)
        
        return loss

    def backward(self, dout=1):
        
        ds = self.loss_layer.backward(dout)
        da = self.out_layer.backward(ds)
        da *= 0.5
        self.in_layer1.backward(da)
        self.in_layer0.backward(da)
        
        return None

# %% [markdown]
# ### 3.4.1 학습 코드 구현

# %%
from common.trainer import Trainer
from common.optimizer import Adam
from common.util import preprocess, create_contexts_target, convert_one_hot

window_size = 1
hidden_size = 5
batch_size = 3
max_epoch = 1000

text = 'You say goodbye and I say hello.'
corpus, word_to_id, id_to_word = preprocess(text)

vocab_size = len(word_to_id)
contexts, target = create_contexts_target(corpus, window_size)
target = convert_one_hot(target, vocab_size)
contexts = convert_one_hot(contexts, vocab_size)

model = SimpleCBOW(vocab_size, hidden_size)
optimizer = Adam()
trainer = Trainer(model, optimizer)

trainer.fit(contexts, target, max_epoch, batch_size)
trainer.plot()
# Out:
# | 에폭 1 |  반복 1 / 2 | 시간 0[s] | 손실 1.95
# | 에폭 2 |  반복 1 / 2 | 시간 0[s] | 손실 1.95
# | 에폭 3 |  반복 1 / 2 | 시간 0[s] | 손실 1.95
# | 에폭 4 |  반복 1 / 2 | 시간 0[s] | 손실 1.95
# | 에폭 5 |  반복 1 / 2 | 시간 0[s] | 손실 1.95
# | 에폭 6 |  반복 1 / 2 | 시간 0[s] | 손실 1.95
# | 에폭 7 |  반복 1 / 2 | 시간 0[s] | 손실 1.95
# | 에폭 8 |  반복 1 / 2 | 시간 0[s] | 손실 1.95
# | 에폭 9 |  반복 1 / 2 | 시간 0[s] | 손실 1.95
# | 에폭 10 |  반복 1 / 2 | 시간 0[s] | 손실 1.95
# | 에폭 11 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 12 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 13 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 14 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 15 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 16 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 17 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 18 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 19 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 20 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 21 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 22 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 23 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# | 에폭 24 |  반복 1 / 2 | 시간 0[s] | 손실 1.94
# ...

# %%
word_vecs = model.word_vecs
for word_id, word in id_to_word.items():
    print(word, word_vecs[word_id])
# Out:
# you [-0.9853038   1.7652667  -0.85938716  0.9055451  -0.9102501 ]
# say [ 1.13738     1.2321299   0.16862194 -1.2481267   1.1929979 ]
# goodbye [-0.96051234 -0.36172196 -0.9934544   1.0839174  -1.1309842 ]
# and [ 1.2722627   1.1138732   1.8671619  -0.72294533  0.67579997]
# i [-0.9394031 -0.345216  -0.9989818  1.0958563 -1.1144595]
# hello [-0.9894892   1.7722806  -0.8224559   0.8901605  -0.90743196]
# . [-0.4416239  1.0162722 -1.7009492 -1.2765177  1.2803298]

# %% [markdown]
# **-> 이 밀집벡터가 단어의 분산 표현!**

# %% [markdown]
# ## 3.5 word2vec 보충

# %% [markdown]
# ### 3.5.1 CBOW 모델과 확률

# %% [markdown]
# **음의 로그 가능도**: CBOW 모델의 손실함수

# %%
Image("image/e 3-3.png")

# %% [markdown]
# ### 3.5.2 skip-gram 모델

# %%
Image("image/fig 3-23.png")

# %% [markdown]
# - skip-gram은 CBOW에서 다루는 맥락과 타깃을 역전시킨 모델
# - 즉, 중앙의 단어로부터 주변의 여러 단어를 추측

# %%
Image("image/fig 3-24.png")

# %% [markdown]
# **skip-gram의 손실함수**

# %%
Image("image/e 3-7.png")

# %% [markdown]
# - 단어 분산 표현의 정밀도 면에서 skip-gram 모델의 결과가 더 좋은 경우가 많음!
# - 속도 면에서는 CBOW 모델이 더 빠름 (skip-gram의 경우 맥락의 수만큼 추측해야하기 때문에 손실을 그만큼 구해서 더해야 함)
